# %% [markdown]
# # *Guided Project: Visualizing The Gender Gap In College Degrees*
#
# **Here we have dataset complied by Randal Olson, a data scientist at University of Pennsylvania. This data set (<a href="http://www.randalolson.com/wp-content/uploads/percent-bachelors-degrees-women-usa.csv">compiled here</a>) will help us explore the gender gap in STEM fields(Science, Technology, Engineering, and Mathematics). This gap is reported on often in the news and not everyone agrees that there is a gap.**
#
# **Here, we'll explore how we can communicate the nuanced narrative of gender gap using effective data visualization.**

# %% [markdown]
# ### Introduction
# 1. Use the starter code in the notebook to get familiar with the data set and the visualization we created at the end of the last mission.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False)
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %% [markdown]
# ### Comparing Across All Degrees
#
# 1. Generate a 6 row by 3 column grid of subplots.
# 2. In the first column:
#     - Generate line charts for both male and female percentages for every degree in stem_cats.
#     - Add text annotations for Women and Men in the topmost and bottommost plots.
# 3. In the second column:
#     - Generate line charts for both male and female percentages for every degree in lib_arts_cats.
#     - Add text annotations for Women and Men for only the topmost plot (since the lines overlap at the end in the bottommost plot).
# 4. In the third column:
#     - Generate line charts for both male and female percentages for every degree in other_cats.
#     - Add text annotations for Women and Men in the topmost and bottommost plots.

# %%
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 
                 'Art and Performance', 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration', 'Education', 
              'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(15, 24))

for sp in range(6):
    ax = fig.add_subplot(6, 3, (sp*3)+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False)
    
    if sp == 0:
        ax.text(2006, 87, 'Men')
        ax.text(2003, 8, 'Women')
    elif sp == 5:
        ax.text(2006, 62, 'Men')
        ax.text(2003, 35, 'Women')
    
    # For other_cats
    ax2 = fig.add_subplot(6, 3, (sp*3)+3)
    ax2.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax2.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax2.spines["right"].set_visible(False)    
    ax2.spines["left"].set_visible(False)
    ax2.spines["top"].set_visible(False)    
    ax2.spines["bottom"].set_visible(False)
    ax2.set_xlim(1968, 2011)
    ax2.set_ylim(0,100)
    ax2.set_title(other_cats[sp])
    ax2.tick_params(bottom=False, top=False, left=False, right=False)
    
    if sp == 0:
        ax2.text(2003, 90, 'Women')
        ax2.text(2006, 7, 'Men')
    elif sp == 5:
        ax2.text(2003, 36, 'Women')
        ax2.text(2006, 62, 'Men')
    
    
    # For lib_arts_cats
for sp in range(5):
    ax1 = fig.add_subplot(6, 3, (sp*3)+2)
    ax1.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax1.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax1.spines["right"].set_visible(False)    
    ax1.spines["left"].set_visible(False)
    ax1.spines["top"].set_visible(False)    
    ax1.spines["bottom"].set_visible(False)
    ax1.set_xlim(1968, 2011)
    ax1.set_ylim(0,100)
    ax1.set_title(lib_arts_cats[sp])
    ax1.tick_params(bottom=False, top=False, left=False, right=False)
    
    if sp == 0:
        ax1.text(2003, 75, 'Women')
        ax1.text(2006, 20, 'Men')
    elif sp == 4:
        ax1.text(2003, 38, 'Women')
        ax1.text(2006, 56, 'Men')
    
plt.show()

# %% [markdown]
# ### Hiding x-axis Labels
#
# 1. Disable the x-axis labels for all line charts except the bottommost line charts in each column.
# 2. Click here to see what the diagram should look like.

# %%
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 
                 'Art and Performance', 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration', 'Education', 
              'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(15, 18))

for sp in range(6):
    ax = fig.add_subplot(6, 3, (sp*3)+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    
    if sp == 0:
        ax.text(2006, 87, 'Men')
        ax.text(2003, 8, 'Women')
    elif sp == 5:
        ax.text(2006, 62, 'Men')
        ax.text(2003, 35, 'Women')
        ax.tick_params(labelbottom=True)
    
    # For other_cats
    ax2 = fig.add_subplot(6, 3, (sp*3)+3)
    ax2.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax2.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax2.spines["right"].set_visible(False)    
    ax2.spines["left"].set_visible(False)
    ax2.spines["top"].set_visible(False)    
    ax2.spines["bottom"].set_visible(False)
    ax2.set_xlim(1968, 2011)
    ax2.set_ylim(0,100)
    ax2.set_title(other_cats[sp])
    ax2.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    
    if sp == 0:
        ax2.text(2003, 91, 'Women')
        ax2.text(2006, 5, 'Men')
    elif sp == 5:
        ax2.text(2003, 32, 'Women')
        ax2.text(2006, 62, 'Men')
        ax2.tick_params(labelbottom=True)
    
    
    # For lib_arts_cats
for sp in range(5):
    ax1 = fig.add_subplot(6, 3, (sp*3)+2)
    ax1.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax1.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax1.spines["right"].set_visible(False)    
    ax1.spines["left"].set_visible(False)
    ax1.spines["top"].set_visible(False)    
    ax1.spines["bottom"].set_visible(False)
    ax1.set_xlim(1968, 2011)
    ax1.set_ylim(0,100)
    ax1.set_title(lib_arts_cats[sp])
    ax1.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    
    if sp == 0:
        ax1.text(2003, 75, 'Women')
        ax1.text(2006, 20, 'Men')
    elif sp == 4:
        ax1.text(2003, 38, 'Women')
        ax1.text(2006, 56, 'Men')
        ax1.tick_params(labelbottom=True)
    
plt.show()

# %% [markdown]
# ### Setting y-axis Labels
#
# 1. For all plots:
#     - Enable just the y-axis labels at 0 and 100.
# 2. Click here to see what the diagram should look like.

# %%
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 
                 'Art and Performance', 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration', 'Education', 
              'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(15, 18))

for sp in range(6):
    ax = fig.add_subplot(6, 3, (sp*3)+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.set_yticks([0,100])
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    
    if sp == 0:
        ax.text(2006, 87, 'Men')
        ax.text(2003, 8, 'Women')
    elif sp == 5:
        ax.text(2006, 62, 'Men')
        ax.text(2003, 35, 'Women')
        ax.tick_params(labelbottom=True)
    
    # For other_cats
    ax2 = fig.add_subplot(6, 3, (sp*3)+3)
    ax2.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax2.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax2.spines["right"].set_visible(False)    
    ax2.spines["left"].set_visible(False)
    ax2.spines["top"].set_visible(False)    
    ax2.spines["bottom"].set_visible(False)
    ax2.set_xlim(1968, 2011)
    ax2.set_ylim(0,100)
    ax2.set_title(other_cats[sp])
    ax2.set_yticks([0,100])
    ax2.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    
    if sp == 0:
        ax2.text(2003, 91, 'Women')
        ax2.text(2006, 5, 'Men')
    elif sp == 5:
        ax2.text(2003, 32, 'Women')
        ax2.text(2006, 62, 'Men')
        ax2.tick_params(labelbottom=True)
    
    
    # For lib_arts_cats
for sp in range(5):
    ax1 = fig.add_subplot(6, 3, (sp*3)+2)
    ax1.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax1.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax1.spines["right"].set_visible(False)    
    ax1.spines["left"].set_visible(False)
    ax1.spines["top"].set_visible(False)    
    ax1.spines["bottom"].set_visible(False)
    ax1.set_xlim(1968, 2011)
    ax1.set_ylim(0,100)
    ax1.set_title(lib_arts_cats[sp])
    ax1.set_yticks([0,100])
    ax1.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    
    if sp == 0:
        ax1.text(2003, 75, 'Women')
        ax1.text(2006, 20, 'Men')
    elif sp == 4:
        ax1.text(2003, 38, 'Women')
        ax1.text(2006, 56, 'Men')
        ax1.tick_params(labelbottom=True)
    
plt.show()

# %% [markdown]
# ### Adding A Horizontal Line
#
# 1. For all plots:
#     - Generate a horizontal line with the following properties:
#        - Starts at the y-axis position 50
#        - Set to the third color (light gray) in the Color Blind 10 palette
#        - Has a transparency of 0.3
# 2. Click here to see what the diagram should look like.

# %%
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 
                 'Art and Performance', 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration', 'Education', 
              'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(15, 18))

for sp in range(6):
    ax = fig.add_subplot(6, 3, (sp*3)+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    
    if sp == 0:
        ax.text(2006, 87, 'Men')
        ax.text(2003, 8, 'Women')
    elif sp == 5:
        ax.text(2006, 62, 'Men')
        ax.text(2003, 35, 'Women')
        ax.tick_params(labelbottom=True)
    
    # For other_cats
    ax2 = fig.add_subplot(6, 3, (sp*3)+3)
    ax2.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax2.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax2.spines["right"].set_visible(False)    
    ax2.spines["left"].set_visible(False)
    ax2.spines["top"].set_visible(False)    
    ax2.spines["bottom"].set_visible(False)
    ax2.set_xlim(1968, 2011)
    ax2.set_ylim(0,100)
    ax2.set_title(other_cats[sp])
    ax2.set_yticks([0,100])
    ax2.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax2.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    
    if sp == 0:
        ax2.text(2003, 91, 'Women')
        ax2.text(2006, 5, 'Men')
    elif sp == 5:
        ax2.text(2003, 32, 'Women')
        ax2.text(2006, 62, 'Men')
        ax2.tick_params(labelbottom=True)
    
    
    # For lib_arts_cats
for sp in range(5):
    ax1 = fig.add_subplot(6, 3, (sp*3)+2)
    ax1.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax1.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax1.spines["right"].set_visible(False)    
    ax1.spines["left"].set_visible(False)
    ax1.spines["top"].set_visible(False)    
    ax1.spines["bottom"].set_visible(False)
    ax1.set_xlim(1968, 2011)
    ax1.set_ylim(0,100)
    ax1.set_title(lib_arts_cats[sp])
    ax1.set_yticks([0,100])
    ax1.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax1.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    
    if sp == 0:
        ax1.text(2003, 75, 'Women')
        ax1.text(2006, 20, 'Men')
    elif sp == 4:
        ax1.text(2003, 38, 'Women')
        ax1.text(2006, 56, 'Men')
        ax1.tick_params(labelbottom=True)
        
plt.show()

# %% [markdown]
# ### Exporting A File
# 1. Export the figure containing all of the line charts to *"gender_degrees.png"*.

# %%
import matplotlib as mpb

lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 
                 'Art and Performance', 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration', 'Education', 
              'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(15, 18))

for sp in range(6):
    # For stem_catss
    ax = fig.add_subplot(6, 3, (sp*3)+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    
    if sp == 0:
        ax.text(2006, 87, 'Men')
        ax.text(2003, 8, 'Women')
    elif sp == 5:
        ax.text(2006, 62, 'Men')
        ax.text(2003, 35, 'Women')
        ax.tick_params(labelbottom=True)
    
    # For other_cats
    ax2 = fig.add_subplot(6, 3, (sp*3)+3)
    ax2.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax2.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax2.spines["right"].set_visible(False)    
    ax2.spines["left"].set_visible(False)
    ax2.spines["top"].set_visible(False)    
    ax2.spines["bottom"].set_visible(False)
    ax2.set_xlim(1968, 2011)
    ax2.set_ylim(0,100)
    ax2.set_title(other_cats[sp])
    ax2.set_yticks([0,100])
    ax2.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax2.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    
    if sp == 0:
        ax2.text(2003, 91, 'Women')
        ax2.text(2006, 5, 'Men')
    elif sp == 5:
        ax2.text(2003, 32, 'Women')
        ax2.text(2006, 62, 'Men')
        ax2.tick_params(labelbottom=True)
    
# For lib_arts_cats
for sp in range(5):
    ax1 = fig.add_subplot(6, 3, (sp*3)+2)
    ax1.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax1.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax1.spines["right"].set_visible(False)    
    ax1.spines["left"].set_visible(False)
    ax1.spines["top"].set_visible(False)    
    ax1.spines["bottom"].set_visible(False)
    ax1.set_xlim(1968, 2011)
    ax1.set_ylim(0,100)
    ax1.set_title(lib_arts_cats[sp])
    ax1.set_yticks([0,100])
    ax1.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax1.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    
    if sp == 0:
        ax1.text(2003, 75, 'Women')
        ax1.text(2006, 20, 'Men')
    elif sp == 4:
        ax1.text(2003, 38, 'Women')
        ax1.text(2006, 56, 'Men')
        ax1.tick_params(labelbottom=True)

print(mpb.get_backend())
plt.savefig("gender_degrees.png")

plt.show()
# Out:
# module://ipykernel.pylab.backend_inline
